# %%
import pandas as pd
import numpy as np

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.2f}".format)

# %%
import os
import pandas as pd

DATA_PATH = r"D:\PROJECT\Airbnb Listings Analysis\dataset"

listings = pd.read_csv(os.path.join(DATA_PATH, "listings.csv"))
neighbourhoods = pd.read_csv(os.path.join(DATA_PATH, "neighbourhoods.csv"))
reviews = pd.read_csv(os.path.join(DATA_PATH, "reviews.csv"))
print("done")
# Out:
# done

# %%
print("Listings shape:", listings.shape)
print("Neighbourhoods shape:", neighbourhoods.shape)
print("Reviews shape:", reviews.shape)
# Out:
# Listings shape: (2876, 18)
# Neighbourhoods shape: (8, 2)
# Reviews shape: (318549, 2)

# %% [markdown]
# Initial Data Inspection

# %%
listings.head()
# Out:
#        id                                               name  host_id  \
# 0  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 1  197263                       Tranquil Room & Private Bath   961396
# 2  209068                                    Terrace Cottage  1029919
# 3  246315                          Asheville Dreamer's Cabin  1292070
# 4  314540  Asheville Urban Farmhouse Entire Home 4.6 mi t...   381660
#
#   host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0   BonPaul                  NaN          28806     35.58     -82.60
# 1   Timothy                  NaN          28806     35.58     -82.64
# 2     Kevin                  NaN          28804     35.62     -82.55
# 3     Annie                  NaN          28805     35.60     -82.51
# 4       Tom                  NaN          28806     35.59     -82.63
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt  95.00               1                454  2025-06-14
# 1     Private room  44.00               2                 87  2024-09-08
# 2  Entire home/apt  90.00              30                 67  2025-05-03
# 3     Private room  61.00               7                 53  2019-10-30
# 4  Entire home/apt 200.00               1                 35  2025-06-13
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               2.69                               8               162
# 1               0.56                               2                73
# 2               0.40                               1               268
# 3               0.32                               3                62
# 4               0.22                               1               139
#
#    number_of_reviews_ltm  license
# 0                     16      NaN
# 1                      5      NaN
# 2                      2      NaN
# 3                      0      NaN
# 4                     11      NaN

# %%
reviews.head()
# Out:
#    listing_id        date
# 0      155305  2011-07-31
# 1      155305  2011-08-23
# 2      155305  2011-09-19
# 3      155305  2011-10-28
# 4      155305  2012-07-01

# %%
neighbourhoods.head()
# Out:
#    neighbourhood_group  neighbourhood
# 0                  NaN          28704
# 1                  NaN          28715
# 2                  NaN          28732
# 3                  NaN          28801
# 4                  NaN          28803

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318549 entries, 0 to 318548
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  318549 non-null  int64
#  1   date        318549 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 4.9+ MB

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2876 entries, 0 to 2875
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2876 non-null   int64
#  1   name                            2876 non-null   object
#  2   host_id                         2876 non-null   int64
#  3   host_name                       2876 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   2876 non-null   int64
#  6   latitude                        2876 non-null   float64
#  7   longitude                       2876 non-null   float64
#  8   room_type                       2876 non-null   object
#  9   price                           2536 non-null   float64
#  10  minimum_nights                  2876 non-null   int64
#  11  number_of_reviews               2876 non-null   int64
#  12  last_review                     2613 non-null   object
#  13  reviews_per_month               2613 non-null   float64
#  14  calculated_host_listings_count  2876 non-null   int64
#  15  availability_365                2876 non-null   int64
#  16  number_of_reviews_ltm           2876 non-null   int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(8), object(4)
# memory usage: 404.6+ KB

# %%
neighbourhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        8 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 260.0 bytes

# %% [markdown]
# Missing Value Inspection

# %%
listings.isna().sum().sort_values(ascending=False)
# Out:
# license                           2876
# neighbourhood_group               2876
# price                              340
# reviews_per_month                  263
# last_review                        263
# id                                   0
# name                                 0
# neighbourhood                        0
# host_name                            0
# host_id                              0
# room_type                            0
# longitude                            0
# latitude                             0
# number_of_reviews                    0
# minimum_nights                       0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
(listings.isna().mean() * 100).sort_values(ascending=False)
# Out:
# license                          100.00
# neighbourhood_group              100.00
# price                             11.82
# reviews_per_month                  9.14
# last_review                        9.14
# id                                 0.00
# name                               0.00
# neighbourhood                      0.00
# host_name                          0.00
# host_id                            0.00
# room_type                          0.00
# longitude                          0.00
# latitude                           0.00
# number_of_reviews                  0.00
# minimum_nights                     0.00
# calculated_host_listings_count     0.00
# availability_365                   0.00
# number_of_reviews_ltm              0.00
# dtype: float64

# %%
listings[[
    "neighbourhood_group",
    "neighbourhood",
    "price",
    "room_type",
    "reviews_per_month",
    "last_review"
]].isna().mean() * 100
# Out:
# neighbourhood_group   100.00
# neighbourhood           0.00
# price                  11.82
# room_type               0.00
# reviews_per_month       9.14
# last_review             9.14
# dtype: float64

# %% [markdown]
# CLEANING ACTIONS

# %%
#Step 1: Drop Useless Columns
listings.drop(
    columns=["license", "neighbourhood_group"],
    inplace=True,
    errors="ignore"
)

# %%
#Step 2: Handle Missing Prices
listings[listings["price"].isna()].shape


#listings[listings["price"].isna()].shape
listings = listings.dropna(subset=["price"])

# %%
listings.isna().sum()
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                       204
# reviews_per_month                 204
# calculated_host_listings_count      0
# availability_365                    0
# number_of_reviews_ltm               0
# dtype: int64

# %%
#Business Interpretation (Important)

About 9% of listings have no review activity

This indicates:

New supply entering the market

Or low-performing listings

This helps in demand segmentation later
