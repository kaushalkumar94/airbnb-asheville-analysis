# %% [markdown]
# # Descriptive Analysis – Phase 2
# This section explores pricing, room type distribution,
# and neighborhood-level listing activity.

# %%
import pandas as pd

listings = pd.read_csv(
    r"D:\PROJECT\Airbnb Listings Analysis\dataset\processed\clean_listings.csv"
)

# %%
listings.shape
# Out:
# (2511, 16)

# %%
listings.head()
# Out:
#        id                                               name  host_id  \
# 0  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 1  197263                       Tranquil Room & Private Bath   961396
# 2  209068                                    Terrace Cottage  1029919
# 3  246315                          Asheville Dreamer's Cabin  1292070
# 4  314540  Asheville Urban Farmhouse Entire Home 4.6 mi t...   381660
#
#   host_name  neighbourhood   latitude  longitude        room_type  price  \
# 0   BonPaul          28806  35.578640 -82.595780  Entire home/apt   95.0
# 1   Timothy          28806  35.577350 -82.638040     Private room   44.0
# 2     Kevin          28804  35.617641 -82.551819  Entire home/apt   90.0
# 3     Annie          28805  35.596150 -82.506350     Private room   61.0
# 4       Tom          28806  35.585610 -82.627310  Entire home/apt  200.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
listings["price"].agg(["mean", "median", "min", "max", "std"])
# Out:
# mean       167.124652
# median     127.000000
# min         20.000000
# max       1000.000000
# std        127.182104
# Name: price, dtype: float64

# %% [markdown]
# ### Overall Pricing Insights
#
# - The average nightly price in Asheville is approximately $167
# - The median price is significantly lower at $127, indicating a right-skewed price distribution
# - Most listings are priced in the mid-range, with a small number of high-priced properties pulling the average upward
# - The wide standard deviation suggests substantial price variability across listings

# %%
listings["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    2264
# Private room        227
# Hotel room           12
# Shared room           8
# Name: count, dtype: int64
